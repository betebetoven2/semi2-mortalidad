# %%
# Correr esto UNA SOLA VEZ, en cualquier notebook o en una celda nueva suelta
spark.sql("""
CREATE TABLE IF NOT EXISTS dw.etl_control_log (
    ejecucion_id   BIGINT GENERATED ALWAYS AS IDENTITY,
    notebook       STRING,
    fecha_inicio   TIMESTAMP,
    fecha_fin      TIMESTAMP,
    estado         STRING,
    filas_salida   BIGINT,
    es_idempotente BOOLEAN,
    nota           STRING
)
""")
# Out:
# DataFrame[]
